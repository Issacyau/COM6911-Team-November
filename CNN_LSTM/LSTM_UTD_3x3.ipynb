# %% [markdown]
# CNN_LSTM_kernel_size_3x3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader

# %%
# Set random seed for numpy
np.random.seed(11)
# Set random seed for pytorch
torch.manual_seed(11)
# Set random seed for pytorch running in GPU
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(11)

# %%
UTD_train_features = np.load('utd/UTD-single-column/sig_train_32_AI.npy',allow_pickle=True)
UTD_test_features = np.load('utd/UTD-single-column/sig_test_32_AI.npy',allow_pickle=True)
UTD_train_labels = np.load('utd/UTD-single-column/sig_train_32_labels.npy',allow_pickle=True)
UTD_test_labels = np.load('utd/UTD-single-column/sig_test_32_labels.npy',allow_pickle=True)

# %%
# Hyperparameters
num_epochs = 30
batch_size = 10
learning_rate = 0.0001

# %%
UTD_train_labels = UTD_train_labels.astype(int) - 1
UTD_test_labels = UTD_test_labels.astype(int) - 1

# %%
# Transform to torch tensor
tensor_UTD_train_features = torch.Tensor(UTD_train_features) 
tensor_UTD_train_labels = torch.Tensor(UTD_train_labels)
tensor_UTD_test_features = torch.Tensor(UTD_test_features) 
tensor_UTD_test_labels = torch.Tensor(UTD_test_labels)
# Add one dimension of channel
tensor_UTD_train_features = torch.unsqueeze(tensor_UTD_train_features, 1)
tensor_UTD_test_features = torch.unsqueeze(tensor_UTD_test_features, 1)
# Create datset
train_dataset_UTD = TensorDataset(tensor_UTD_train_features,tensor_UTD_train_labels)
test_dataset_UTD = TensorDataset(tensor_UTD_test_features,tensor_UTD_test_labels)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset_UTD, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset_UTD, batch_size=batch_size, shuffle=False)

# %%
for image,label in train_loader:
    print(image.size())
    print(label.size())
    break
# Out:
# torch.Size([10, 1, 18, 32])
# torch.Size([10])

# %% [markdown]
# ### Construct LSTM

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
class Cnn(nn.Module):
    def __init__(self):
        super(Cnn, self).__init__()
        self.conv1 = nn.Conv2d(1,32, kernel_size=3, stride=1, padding=1)  ### 10,32,18,384
        self.pool = nn.MaxPool2d(2, 2) ### 10,32,9,192 2nd layer
        self.conv2 = nn.Conv2d(32,64, kernel_size=3, stride=1, padding=1) ###10,64,9,192 3rd layer
    
    def forward(self, x):
        batch,c,h,w = x.size()
        x = self.pool(F.relu(self.conv1(x)))
        x = (F.relu(self.conv2(x))) ### 10,64,9,192/ 5,64,9,192
        x = x.view(batch,-1) ### 10,110592 
        return x

# %%
class CNN_LSTM(nn.Module): 
    def __init__(self):
        super(CNN_LSTM, self).__init__() ###(num_samples,timesteps,input_dim). 
        self.cnn = Cnn()
        self.rnn = nn.LSTM(
            input_size=72, ### [32 <- 216] / [64<-432]/ [128<-864] or single [32 <- 72] / [64<-144]/ [128<-288]
            hidden_size=441, 
            num_layers=5, ### change [1,3,5]
            batch_first=True)
        self.linear = nn.Linear(441,21)

    def forward(self, x):
        batch,c,h,w = x.size()
        c_out = self.cnn(x) ### 10,110592
        r_in = c_out.view(batch,128,-1) ### 10,1,8192
        r_out, (h_n, h_c) = self.rnn(r_in)
        r_out2 = self.linear(r_out[:, -1, :])
        return F.log_softmax(r_out2, dim=1)

# %%
# Choose CPU or GPU
# model = ConvNet() #CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = CNN_LSTM().to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Combine

# %%
# %%time
total_step = len(train_loader)
loss_list = []
acc_list = []
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        # Run the forward pass
        outputs = model(images)
        loss = criterion(outputs, labels.to(device).long())
        loss_list.append(loss.item())

        # Backprop and perform Adam optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Track the accuracy
        total = labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        acc_list.append(correct / total)

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
# Out:
# Epoch [1/30], Step [100/364], Loss: 2.8992, Accuracy: 10.00%
# Epoch [1/30], Step [200/364], Loss: 2.7573, Accuracy: 20.00%
# Epoch [1/30], Step [300/364], Loss: 2.7676, Accuracy: 20.00%
# Epoch [2/30], Step [100/364], Loss: 1.8943, Accuracy: 30.00%
# Epoch [2/30], Step [200/364], Loss: 2.5524, Accuracy: 20.00%
# Epoch [2/30], Step [300/364], Loss: 2.6163, Accuracy: 20.00%
# Epoch [3/30], Step [100/364], Loss: 2.3488, Accuracy: 10.00%
# Epoch [3/30], Step [200/364], Loss: 2.3137, Accuracy: 40.00%
# Epoch [3/30], Step [300/364], Loss: 2.3286, Accuracy: 10.00%
# Epoch [4/30], Step [100/364], Loss: 1.6114, Accuracy: 60.00%
# Epoch [4/30], Step [200/364], Loss: 2.4502, Accuracy: 10.00%
# Epoch [4/30], Step [300/364], Loss: 2.0669, Accuracy: 30.00%
# Epoch [5/30], Step [100/364], Loss: 2.1053, Accuracy: 40.00%
# Epoch [5/30], Step [200/364], Loss: 2.2030, Accuracy: 10.00%
# Epoch [5/30], Step [300/364], Loss: 1.7765, Accuracy: 40.00%
# Epoch [6/30], Step [100/364], Loss: 1.9302, Accuracy: 40.00%
# Epoch [6/30], Step [200/364], Loss: 1.6096, Accuracy: 50.00%
# Epoch [6/30], Step [300/364], Loss: 2.4055, Accuracy: 10.00%
# Epoch [7/30], Step [100/364], Loss: 1.9692, Accuracy: 50.00%
# Epoch [7/30], Step [200/364], Loss: 1.8920, Accuracy: 50.00%
# Epoch [7/30], Step [300/364], Loss: 1.6406, Accuracy: 60.00%
# Epoch [8/30], Step [100/364], Loss: 2.1338, Accuracy: 40.00%
# Epoch [8/30], Step [200/364], Loss: 1.8562, Accuracy: 30.00%
# Epoch [8/30], Step [300/364], Loss: 1.2439, Accuracy: 50.00%
# Epoch [9/30], Step [100/364], Loss: 1.6034, Accuracy: 60.00%
# Epoch [9/30], Step [200/364], Loss: 1.7263, Accuracy: 30.00%
# Epoch [9/30], Step [300/364], Loss: 1.5755, Accuracy: 50.00%
# Epoch [10/30], Step [100/364], Loss: 1.4142, Accuracy: 50.00%
# Epoch [10/30], Step [200/364], Loss: 2.1912, Accuracy: 50.00%
# Epoch [10/30], Step [300/364], Loss: 1.3920, Accuracy: 60.00%
# Epoch [11/30], Step [100/364], Loss: 1.5097, Accuracy: 40.00%
# Epoch [11/30], Step [200/364], Loss: 1.6954, Accuracy: 50.00%
# Epoch [11/30], Step [300/364], Loss: 1.2634, Accuracy: 60.00%
# Epoch [12/30], Step [100/364], Loss: 1.9892, Accuracy: 30.00%
# Epoch [12/30], Step [200/364], Loss: 1.7769, Accuracy: 50.00%
# Epoch [12/30], Step [300/364], Loss: 1.3391, Accuracy: 50.00%
# Epoch [13/30], Step [100/364], Loss: 1.0010, Accuracy: 70.00%
# Epoch [13/30], Step [200/364], Loss: 1.3262, Accuracy: 60.00%
# Epoch [13/30], Step [300/364], Loss: 1.2913, Accuracy: 60.00%
# Epoch [14/30], Step [100/364], Loss: 2.1409, Accuracy: 40.00%
# Epoch [14/30], Step [200/364], Loss: 1.7705, Accuracy: 40.00%
# Epoch [14/30], Step [300/364], Loss: 0.9721, Accuracy: 70.00%
# Epoch [15/30], Step [100/364], Loss: 1.4487, Accuracy: 60.00%
# Epoch [15/30], Step [200/364], Loss: 0.9716, Accuracy: 80.00%
# Epoch [15/30], Step [300/364], Loss: 1.1795, Accuracy: 70.00%
# Epoch [16/30], Step [100/364], Loss: 1.0249, Accuracy: 60.00%
# Epoch [16/30], Step [200/364], Loss: 1.3538, Accuracy: 60.00%
# Epoch [16/30], Step [300/364], Loss: 1.3234, Accuracy: 60.00%
# Epoch [17/30], Step [100/364], Loss: 1.6252, Accuracy: 40.00%
# Epoch [17/30], Step [200/364], Loss: 1.9284, Accuracy: 30.00%
# Epoch [17/30], Step [300/364], Loss: 0.9412, Accuracy: 70.00%
# Epoch [18/30], Step [100/364], Loss: 1.8487, Accuracy: 40.00%
# Epoch [18/30], Step [200/364], Loss: 0.6470, Accuracy: 70.00%
# Epoch [18/30], Step [300/364], Loss: 0.3045, Accuracy: 100.00%
# Epoch [19/30], Step [100/364], Loss: 0.3931, Accuracy: 80.00%
# Epoch [19/30], Step [200/364], Loss: 1.8643, Accuracy: 30.00%
# Epoch [19/30], Step [300/364], Loss: 0.6977, Accuracy: 80.00%
# Epoch [20/30], Step [100/364], Loss: 1.4713, Accuracy: 50.00%
# Epoch [20/30], Step [200/364], Loss: 0.9754, Accuracy: 70.00%
# Epoch [20/30], Step [300/364], Loss: 1.4409, Accuracy: 40.00%
# Epoch [21/30], Step [100/364], Loss: 0.6283, Accuracy: 80.00%
# Epoch [21/30], Step [200/364], Loss: 1.7197, Accuracy: 60.00%
# Epoch [21/30], Step [300/364], Loss: 1.2825, Accuracy: 60.00%
# Epoch [22/30], Step [100/364], Loss: 0.9090, Accuracy: 60.00%
# Epoch [22/30], Step [200/364], Loss: 1.7637, Accuracy: 40.00%
# Epoch [22/30], Step [300/364], Loss: 1.3634, Accuracy: 60.00%
# Epoch [23/30], Step [100/364], Loss: 0.7341, Accuracy: 90.00%
# Epoch [23/30], Step [200/364], Loss: 0.6368, Accuracy: 80.00%
# Epoch [23/30], Step [300/364], Loss: 0.8404, Accuracy: 70.00%
# Epoch [24/30], Step [100/364], Loss: 0.6468, Accuracy: 80.00%
# Epoch [24/30], Step [200/364], Loss: 0.9804, Accuracy: 70.00%
# Epoch [24/30], Step [300/364], Loss: 1.1022, Accuracy: 50.00%
# Epoch [25/30], Step [100/364], Loss: 0.5213, Accuracy: 90.00%
# Epoch [25/30], Step [200/364], Loss: 0.8253, Accuracy: 70.00%
# Epoch [25/30], Step [300/364], Loss: 0.5647, Accuracy: 80.00%
# Epoch [26/30], Step [100/364], Loss: 0.9610, Accuracy: 60.00%
# Epoch [26/30], Step [200/364], Loss: 0.5797, Accuracy: 80.00%
# Epoch [26/30], Step [300/364], Loss: 0.9255, Accuracy: 50.00%
# Epoch [27/30], Step [100/364], Loss: 1.0268, Accuracy: 70.00%
# Epoch [27/30], Step [200/364], Loss: 0.7158, Accuracy: 60.00%
# Epoch [27/30], Step [300/364], Loss: 1.2056, Accuracy: 70.00%
# Epoch [28/30], Step [100/364], Loss: 1.8748, Accuracy: 40.00%
# Epoch [28/30], Step [200/364], Loss: 0.8896, Accuracy: 60.00%
# Epoch [28/30], Step [300/364], Loss: 0.7852, Accuracy: 70.00%
# Epoch [29/30], Step [100/364], Loss: 0.7043, Accuracy: 70.00%
# Epoch [29/30], Step [200/364], Loss: 0.2842, Accuracy: 90.00%
# Epoch [29/30], Step [300/364], Loss: 0.4538, Accuracy: 90.00%
# Epoch [30/30], Step [100/364], Loss: 0.5982, Accuracy: 90.00%
# Epoch [30/30], Step [200/364], Loss: 0.9204, Accuracy: 70.00%
# Epoch [30/30], Step [300/364], Loss: 0.5282, Accuracy: 90.00%
# CPU times: user 7h 54min 58s, sys: 29min 26s, total: 8h 24min 24s
# Wall time: 8h 21min 26s

# %%
classes = ('Swipe_left','Swipe_right','Wave',"Clap","Throw","Arm_cross","Basketball_shoot","Draw_X",
           "Draw_circle_clockwise","Draw_circle_counter","Draw_traingle","Bowling","Boxing","Baseball_swing",
          "Tennis_swing","Arm_curl","Tennis_serve","Push","Knock","Catch","Pickup_throw")

# %%
from sklearn import metrics
import seaborn as sns
# Test the model on GPU
model.eval()
all_labels = []
all_predictions = []
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        outputs = model(images.to(device))
        _, predicted = torch.max(outputs.data, 1)
        all_predictions.append(predicted)
        all_labels.append(labels)
        total += labels.size(0)
        correct += (predicted == labels.to(device)).sum().item()

    print('Test Accuracy of the model on the UCIHAR test images: {} %'.format((correct / total) * 100))

mat = metrics.confusion_matrix(torch.cat(all_predictions).cpu(), torch.cat(all_labels).cpu())
plt.figure(figsize=(7,7))
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=classes, yticklabels=classes)
plt.xlabel('true label')
plt.ylabel('predicted label');
# Out:
# Test Accuracy of the model on the UCIHAR test images: 39.45054945054945 %
